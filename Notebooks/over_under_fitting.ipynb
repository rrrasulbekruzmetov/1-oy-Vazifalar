# %% [markdown]
# # Overfitting va Underfitting nima?

# %% [markdown]
# # Underfitting - model juda sodda bo`lib, malumotlardagi asosiy qiytmatlarni yaxshi o`rgana olmagan holati.

# %% [markdown]
# # Belgilari
# - Train accuracy Past
# - Test Accuracy yoki Validation Past
# - model xatolik katta
# - Bias juda yuqori

# %% [markdown]
# # Matematik jixatdan
# - High Bias
# - Low Variance

# %% [markdown]
# # Xulosa : Modelning train natijasi ham Test natijasi ham  yamon chiqadi

# %% [markdown]
# # Underfittingni oldini olish yechimlari
#
# - Modelni murakkablashtirish
# - Ko`proq feature qo`shish
# - Polynomial features
# - Kamroq Regularization berish

# %% [markdown]
# # Overfitting

# %% [markdown]
# # Overfitting - bu model train datani yodalb olgan, trainda  natija juda baland lekin yangi malumotlartda natija yamon

# %% [markdown]
# # Xulosa : Model berilgan malumotni yodlab olgan

# %% [markdown]
# # Belgilari:
# - Train accuracy baland (95-100)
# - Validation / testr accuracy past chiqadi
# - Model juda sezgir
# - Variance juda yuqori

# %% [markdown]
# # Matematik jixatdan
# - Low Bias
# - High Variance

# %% [markdown]
# # Overfittingni oldini olish yechimlari
#
# - Regularization  (L1 L2)
# - Modelni Soddalashtirish
# - max_depth, min_samples_leaf
# - Ko`proq yaxshi data berish
# - Dropout data  (Deep Learningda)
# - Cross Validation ishlatish

# %% [markdown]
# # real Hayotga moslangan misollar
# - Underfitting : Darsni umuman o`qimagan talaba
# - Overfitting :  Savollarni yodlab olgan talaba
#
# - Optimal Xolat:  tushunib o`qib o`rganib olgan talaba

# %% [markdown]
# | Holat        | Train Score | Test Score |
# | ------------ | ----------- | ---------- |
# | Underfitting | Past        | Past       |
# | Overfitting  | Juda yuqori | Past       |
# | Optimal      | Yaxshi      | Yaxshi     |

# %% [markdown]
# | Holat        | Bias        | Variance    |
# | ------------ | ----------- | ----------- |
# | Underfitting | 🔴 High     | 🟢 Low      |
# | Optimal      | 🟢 Balanced | 🟢 Balanced |
# | Overfitting  | 🟢 Low      | 🔴 High     |

# %% [markdown]
# # Bias - bu modelning haqiqiy bo`glanishni no`to`gri taxmin qilishi

# %% [markdown]
# # Model juda soddalashtirib yuborgan bo`ladi

# %% [markdown]
# # Model "xato fikrlayabdi"
# # Asosiy qiymatlarni ham yaxshi ulashmayabdi

# %% [markdown]
# # High Bias degani bu -- Underfitting

# %% [markdown]
# # Belgilari
# - Train error yuqori
# - Test Error yuqori
# - Model natijalari doim yamon chiqadi

# %% [markdown]
# # Matematik jihatdan quyidagicha - Bias kutilayotgan bashorat bilan haqiqiy qiymat orasidagi farq
# - agarda u katta bo`lsa model noto`gri taxmin qilyabdi

# %% [markdown]
# # Biasni kamaytirish usullari
# - Murakkabroq model yaratish
# - Ko`proq feature
# - Ploynomial features
# - Kamroq Regularization

# %% [markdown]
# # Variance -  nima?

# %% [markdown]
# # Variance bu - modelning malumotdagi kichik o`zgarishlarga haddan tashqari sezgirligi

# %% [markdown]
# # Model hamma narsani yodlab olgan

# %% [markdown]
# # Variance yuqori bo`lsa
# - train datada natija zo`r
# - tets datada natija yamon

# %% [markdown]
#  #  High Variance == Overfitting

# %% [markdown]
# # Belgilari
# - Train error juda past
# - test error yuqori
# - model beqaror

# %% [markdown]
# # Matematik Jihatdan -- turli train datasetlarda model natijasining o`zgarishi

# %% [markdown]
# # Misol:
# - Agarda Decision Tree (max_depth= None)
#
# - Train Accuracy = 100%
# - Test Accuracy  = 70%
#
# - Model High Variance

# %% [markdown]
# # Varianceni kamaytirish usullari
# - Regularization (l1 l2)
# - Modelni soddalashtirish
# - Ko`proq data
# - Ensemble modellar tanlash
# - Dropout qilish (DL da)

# %% [markdown]
# # BIAS - VARIANCE TRADEOFF
#
# - Biasni kamaytirsak == Variance oshadi
# - Varianceni kamaytirsak == Bias oshadi

# %% [markdown]
# # Overfitting va Underfitting Amaliyot

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
x = df[["pclass", "sex", "age", "sibsp", "parch", "fare", "embarked"]]
y = df["survived"]

# %%
num_feature = ["age", "sibsp", "parch", "fare"]
cat_feature = ["sex", "embarked", "pclass"]

num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler)
])

cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", pd.get_dummies)
])

# %% [markdown]
# # pipleini ichida pd.get_dummies ishlamay qolsa quyidagi kod ishlaydi

# %%
from sklearn.preprocessing  import OneHotEncoder


cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# %%
preprocessor = ColumnTransformer([
    ("num", num_pipeline, num_feature),
    ("cat", cat_pipeline, cat_feature)
])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# # Underfittinga misol (High Bias)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

num_cols = ["age", "fare"]
cat_cols = ["sex", "embarked"]

# Numerical pipeline
num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# Categorical pipeline
cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer([
    ("num", num_pipeline, num_cols),
    ("cat", cat_pipeline, cat_cols)
])

# %%
underfit_model = Pipeline([
    ("preprocess", preprocessor),
    ("model", LogisticRegression(C=0.01, max_iter=1000))
])

underfit_model.fit(x_train, y_train)

print("Train Score:", underfit_model.score(x_train, y_train))
print("Test Score:", underfit_model.score(x_test, y_test))
# Out:
# Train Score: 0.7612359550561798
# Test Score: 0.7262569832402235

# %% [markdown]
# # Overfittingga misol

# %%
overfit_model = Pipeline([
    ("preprocess", preprocessor),
    ("model", DecisionTreeClassifier(max_depth=None, min_samples_split=2, min_samples_leaf=1, random_state=42))
])

overfit_model.fit(x_train, y_train)

print("Train Score: ", overfit_model.score(x_train, y_train))
print("Test Score: ", overfit_model.score(x_test, y_test))
# Out:
# Train Score:  0.9817415730337079
# Test Score:  0.7877094972067039

# %% [markdown]
# # Regularization bilan Overfitting natijasini  yaxshilash

# %%
regulized_tree = Pipeline([
    ("preprocess", preprocessor),
    ("model", DecisionTreeClassifier(max_depth=4, min_samples_split=10, min_samples_leaf=5, random_state=42))

])

regulized_tree.fit(x_train, y_train)

print("Train Score: ", regulized_tree.score(x_train, y_train))
print("Test Score: ", regulized_tree.score(x_test, y_test))
# Out:
# Train Score:  0.8188202247191011
# Test Score:  0.7541899441340782

# %% [markdown]
# # Cross Validation bilan natijani ko`rish

# %%
cv_scoress = cross_val_score(overfit_model, x_train, y_train, cv=5)

print("Cv mnean", cv_scoress.mean())
# Out:
# Cv mnean 0.7500837190978036

# %% [markdown]
# # bu natijadan biz bilamizki bizda OVERFITTING BO`LGAN

# %%
cv_scoress = cross_val_score(underfit_model, x_train, y_train, cv=5)

print("Cv mnean", cv_scoress.mean())
# Out:
# Cv mnean 0.7486555697823303

# %%
cv_scoress = cross_val_score(regulized_tree, x_train, y_train, cv=5)

print("Cv mnean", cv_scoress.mean())
# Out:
# Cv mnean 0.7935881020388063
