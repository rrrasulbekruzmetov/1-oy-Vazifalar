# %%
import seaborn as sns 
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_One\Data\Raw_Data\atlanta_9-24-2016_9-30-2017.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Commodity Name   57 non-null     object
#  1   City Name        57 non-null     object
#  2   Type             0 non-null      float64
#  3   Package          57 non-null     object
#  4   Variety          57 non-null     object
#  5   Sub Variety      1 non-null      object
#  6   Grade            0 non-null      float64
#  7   Date             57 non-null     object
#  8   Low Price        57 non-null     float64
#  9   High Price       57 non-null     float64
#  10  Mostly Low       57 non-null     float64
#  11  Mostly High      57 non-null     float64
#  12  Origin           57 non-null     object
#  13  Origin District  0 non-null      float64
#  14  Item Size        56 non-null     object
#  15  Color            0 non-null      float64
# ...

# %%
df.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS   ATLANTA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS   ATLANTA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS   ATLANTA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS   ATLANTA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS   ATLANTA   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016      140.0      154.75  ...    NaN          NaN
# 1    NaN  09/24/2016      145.0      154.75  ...    NaN          NaN
# 2    NaN  09/24/2016      150.0      154.75  ...    NaN          NaN
# 3    NaN  09/24/2016      150.0      150.00  ...    NaN          NaN
# 4    NaN  10/01/2016      140.0      154.75  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage  Crop  Repack  \
# ...

# %% [markdown]
# # Datani Split qilish

# %% [markdown]
# # Dataset 3 ta qismga bo`linadi
# - 1-qism : Train - yani modelni o`qitish uchun   == 80%  yoki 70 %
# - 2-qism : Test - yani modelni test qilib korish uchun  == 10 %  == yoki == 15 %
# - 3-qism : Validation - yani modelni baholab olish uchun == 10% == yoki == 15 %

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived    Pclass      Name       Age  \
# 0             0            1         0  0.827377 -1.310217 -0.592481
# 1             1            2         1 -1.566107 -0.991410  0.638789
# 2             2            3         1  0.827377 -0.357685 -0.284663
# 3             3            4         1 -1.566107 -0.672604  0.407926
# 4             4            5         0  0.827377 -1.671790  0.407926
# ..          ...          ...       ...       ...       ...       ...
# 886         886          887         0 -0.369365  0.400452 -0.207709
# 887         887          888         1 -1.566107 -0.552079 -0.823344
# 888         888          889         0  0.827377 -0.124412  0.000000
# 889         889          890         1 -1.566107 -1.415189 -0.284663
# 890         890          891         0  0.827377 -0.874774  0.177063
#
#         SibSp     Parch    Ticket      Fare     Cabin  col_female  col_male  \
# ...

# %% [markdown]
# # Feature Va Targetga ajratish

# %%
x = df.drop(columns=["Cabin"])
y = df["Cabin"]

# %%
y
# Out:
# 0     -0.281881
# 1      1.161545
# 2     -0.281881
# 3      0.057748
# 4     -0.281881
#          ...
# 886   -0.281881
# 887   -1.003594
# 888   -0.281881
# 889    0.270017
# 890   -0.281881
# Name: Cabin, Length: 891, dtype: float64

# %%
x
# Out:
#      Unnamed: 0  PassengerId  Survived    Pclass      Name       Age  \
# 0             0            1         0  0.827377 -1.310217 -0.592481
# 1             1            2         1 -1.566107 -0.991410  0.638789
# 2             2            3         1  0.827377 -0.357685 -0.284663
# 3             3            4         1 -1.566107 -0.672604  0.407926
# 4             4            5         0  0.827377 -1.671790  0.407926
# ..          ...          ...       ...       ...       ...       ...
# 886         886          887         0 -0.369365  0.400452 -0.207709
# 887         887          888         1 -1.566107 -0.552079 -0.823344
# 888         888          889         0  0.827377 -0.124412  0.000000
# 889         889          890         1 -1.566107 -1.415189 -0.284663
# 890         890          891         0  0.827377 -0.874774  0.177063
#
#         SibSp     Parch    Ticket      Fare  col_female  col_male     col_C  \
# ...

# %% [markdown]
# # Train va Temporary split == 70% ga 30 %

# %%
from sklearn.model_selection import train_test_split
x_train, x_temp, y_train, y_temp = train_test_split (x, y, test_size=0.3, random_state=42)

# %%
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
x_val
# Out:
#      Unnamed: 0  PassengerId    Pclass      Name       Age     SibSp  \
# 377         377          378 -1.566107  1.621247 -0.207709 -0.474545
# 244         244          245  0.827377 -1.547377  0.023154 -0.474545
# 72           72           73 -0.369365 -0.268264 -0.669435 -0.474545
# 815         815          816 -1.566107 -0.684267  0.000000 -0.474545
# 841         841          842 -0.369365  0.462658 -1.054207 -0.474545
# ..          ...          ...       ...       ...       ...       ...
# 444         444          445  0.827377 -0.167179  0.000000 -0.474545
# 764         764          765  0.827377 -0.824231 -1.054207 -0.474545
# 743         743          744  0.827377  0.314919 -0.438572  0.432793
# 263         263          264 -1.566107 -0.408228  0.792698 -0.474545
# 730         730          731 -1.566107 -1.675678 -0.053800 -0.474545
#
#         Parch    Ticket      Fare     Cabin  col_female  col_male     col_C  \
# ...

# %%
y_val
# Out:
# 377    0
# 244    0
# 72     0
# 815    0
# 841    0
#       ..
# 444    1
# 764    0
# 743    0
# 263    0
# 730    1
# Name: Survived, Length: 134, dtype: int64

# %%
x_temp
# Out:
#      Unnamed: 0  PassengerId    Pclass      Name       Age     SibSp  \
# 625         625          626 -1.566107  1.356871  2.408739 -0.474545
# 566         566          567  0.827377  1.325768 -0.823344 -0.474545
# 459         459          460  0.827377  0.614286  0.000000 -0.474545
# 804         804          805  0.827377 -0.365461 -0.207709 -0.474545
# 338         338          339  0.827377 -0.983634  1.177469 -0.474545
# ..          ...          ...       ...       ...       ...       ...
# 184         184          185  0.827377 -0.015552 -1.977659 -0.474545
# 607         607          608 -1.566107 -0.956419 -0.207709 -0.474545
# 624         624          625  0.827377 -1.329656 -0.669435 -0.474545
# 103         103          104  0.827377 -0.155515  0.254017 -0.474545
# 387         387          388 -0.369365 -1.271338  0.484880 -0.474545
#
#         Parch    Ticket      Fare     Cabin  col_female  col_male     col_C  \
# ...

# %%
x_test
# Out:
#      Unnamed: 0  PassengerId    Pclass      Name       Age     SibSp  \
# 455         455          456  0.827377 -0.206058 -0.053800 -0.474545
# 607         607          608 -1.566107 -0.956419 -0.207709 -0.474545
# 142         142          143  0.827377 -0.489873 -0.438572  0.432793
# 883         883          884 -0.369365 -1.492947 -0.130754 -0.474545
# 835         835          836 -1.566107 -1.049728  0.715743  0.432793
# ..          ...          ...       ...       ...       ...       ...
# 322         322          323 -0.369365  1.232459  0.023154 -0.474545
# 642         642          643  0.827377  1.216907 -2.131568  2.247470
# 566         566          567  0.827377  1.325768 -0.823344 -0.474545
# 690         690          691 -1.566107 -0.901989  0.100109  0.432793
# 823         823          824  0.827377  0.408228 -0.207709 -0.474545
#
#         Parch    Ticket      Fare     Cabin  col_female  col_male     col_C  \
# ...

# %% [markdown]
# # Quyidagi holatlarga etibor bergan holda tanlovni amalga oshirish
#
# - Kichik Dataset -- Train/ Val/ Test
# - Juda Kichik Datset -- Cross Validation
# - Kattaroq Dataset -- 70 / 15 -15  tavsiya qilinadi
# - Deep Learning - Validation qism majburiy

# %% [markdown]
# # Modelni o`qitish jarayoni

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

model = LinearRegression()

model.fit(x_train, y_train)

y_val_pred = model.predict(x_val)
val_score = r2_score(y_val, y_val_pred)

print("Validation r2_Score :  ", val_score)
# Out:
# Validation r2_Score :   0.03927057629429498

# %%
y_test_pred = model.predict(x_test)
test_accuracy = r2_score(y_test, y_test_pred)

print("Test r2_score: ", test_accuracy)
# Out:
# Test r2_score:  0.12528367710223343

# %%
y_train_pred = model.predict(x_train)

train_accuracy = r2_score(y_train, y_train_pred)

print("Train r2_score: ", train_accuracy)
# Out:
# Train r2_score:  0.0790441129685322
